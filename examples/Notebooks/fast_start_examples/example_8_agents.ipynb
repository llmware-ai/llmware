# %% [markdown]
# ### **If you are using Colab for free, we highly recommend you active the T4 GPU hardware accelerator. Our models are designed to run with at least 16GB of RAM, activating T4 will grant the notebook 16GB of GDDR6 RAM as opposed to the 13GB Colab gives automatically.**
# ### **To active T4:**
# ### **1. click on the "Runtime" tab**
# ### **2. click on "Change runtime type"**
# ### **3. select T4 GPU under Hardware Accelerator**
# ### **NOTE: there is a weekly usage limit on using T4 for free**

# %% [markdown]
# # **Fast Start Example 8 - Agents** #
# This example shows how to build locally-running Agents deploying multiple small specialized function-calling models as tools with an integrated work management, process and journaling capability using the LLMfx class.
#
# This example shows a workflow receiving a customer transcript, and having an agent run through a series of analytical and classification steps.
#
#     1.  Create an agent using the LLMfx class.
#     2.  Load multiple specialized tools for the agent.
#     3.  Execute a series of function-calls.
#     4.  Generate a consolidated automatic dictionary report.

# %% [markdown]
# # Create agent and load tools

# %%
# !pip install llmware
# Out:
# Collecting llmware
#   Downloading llmware-0.3.3-py3-none-any.whl (56.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 MB 12.6 MB/s eta 0:00:00
# Collecting boto3>=1.24.53 (from llmware)
#   Downloading boto3-1.34.146-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from llmware) (0.23.5)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.10/dist-packages (from llmware) (1.25.2)
# Collecting pymongo>=4.7.0 (from llmware)
#   Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from llmware) (0.19.1)
# Collecting psycopg-binary==3.1.17 (from llmware)
#   Downloading psycopg_binary-3.1.17-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 48.4 MB/s eta 0:00:00
# Collecting psycopg==3.1.17 (from llmware)
#   Downloading psycopg-3.1.17-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 23.1 MB/s eta 0:00:00
# Collecting pgvector==0.2.4 (from llmware)
#   Downloading pgvector-0.2.4-py2.py3-none-any.whl (9.6 kB)
# Collecting colorama==0.4.6 (from llmware)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from llmware) (0.10.2.post1)
# Requirement already satisfied: typing-extensions>=4.1 in /usr/local/lib/python3.10/dist-packages (from psycopg==3.1.17->llmware) (4.12.2)
# Collecting botocore<1.35.0,>=1.34.146 (from boto3>=1.24.53->llmware)
#   Downloading botocore-1.34.146-py3-none-any.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 39.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.24.53->llmware)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.24.53->llmware)
#   Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->llmware) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->llmware) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->llmware) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->llmware) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->llmware) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->llmware) (4.66.4)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.0->llmware) (1.0.8)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo>=4.7.0->llmware)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 29.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.146->boto3>=1.24.53->llmware) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.146->boto3>=1.24.53->llmware) (2.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.10.0->llmware) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa>=0.10.0->llmware) (4.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.4->llmware) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.4->llmware) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.4->llmware) (2024.7.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa>=0.10.0->llmware) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa>=0.10.0->llmware) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.10.0->llmware) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.146->boto3>=1.24.53->llmware) (1.16.0)
# Installing collected packages: psycopg-binary, psycopg, pgvector, jmespath, dnspython, colorama, pymongo, botocore, s3transfer, boto3, llmware
# Successfully installed boto3-1.34.146 botocore-1.34.146 colorama-0.4.6 dnspython-2.6.1 jmespath-1.0.1 llmware-0.3.3 pgvector-0.2.4 psycopg-3.1.17 psycopg-binary-3.1.17 pymongo-4.8.0 s3transfer-0.10.2

# %%
from llmware.agents import LLMfx

# %%
agent = LLMfx()

customer_transcript = "My name is Michael Jones, and I am a long-time customer.  " \
                      "The Mixco product is not working currently, and it is having a negative impact " \
                      "on my business, as we can not deliver our products while it is down. " \
                      "This is the fourth time that I have called.  My account number is 93203, and " \
                      "my user name is mjones. Our company is based in Tampa, Florida."

agent.load_work(customer_transcript)
# Out:
# INFO:llmware.agents:Agent - Setting up LLMWare Workspace.
# update: Launching LLMfx process
# step - 	1 - 	creating object - ready to start processing.
# step - 	2 - 	loading new processing text - 1 new entries
# [{'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.',
#   'file_source': 'NA',
#   'page_num': 'NA'}]

# %% [markdown]
# Load individual SLIM tool or multiple tools list

# %%
agent.load_tool("sentiment")
agent.load_tool("ner")

agent.load_tool_list(["emotions", "topics", "intent", "tags", "ratings", "answer"])
# Out:
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-sentiment-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	3 - 	loading tool - sentiment
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/12.0k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# slim-sentiment.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-ner-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	4 - 	loading tool - ner
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/15.9k [00:00<?, ?B/s]
# slim-ner.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-emotions-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	5 - 	loading tool - emotions
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.75k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/12.0k [00:00<?, ?B/s]
# slim-emotions.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-topics-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	6 - 	loading tool - topics
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.72k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# slim-topics.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-intent-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	7 - 	loading tool - intent
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.77k [00:00<?, ?B/s]
# slim-intent.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-tags-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	8 - 	loading tool - tags
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/15.0k [00:00<?, ?B/s]
# slim-tags.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - slim-ratings-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	9 - 	loading tool - ratings
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.73k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/7.53k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.57k [00:00<?, ?B/s]
# slim-ratings.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]
# WARNING:llmware.models:ModelCatalog - load_model - fetching model - bling-answer-tool - from remote repository using pull_snapshot_from_hf - this may take a couple of minutes the first time.
# step - 	10 - 	loading tool - answer
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1194: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/247k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# bling-answer.gguf:   0%|          | 0.00/669M [00:00<?, ?B/s]

# %% [markdown]
# # Deploy tools and run analysis

# %% [markdown]
# Assess "soft skills"

# %%
agent.sentiment()
agent.emotions()
agent.intent()
# Out:
# step - 	11 - 	executing function call - deploying - sentiment
# INFO:llmware.models:update: LocalTokenizer - need to fetch tokenizer - tokenizer_tl.json
# step - 	12 - 	executing function call - getting response - sentiment
# 				 -- llm_response - {'sentiment': ['negative']}
# 				 -- output type - dict
# 				 -- usage - {'input': 107, 'output': 8, 'total': 115, 'metric': 'tokens', 'processing_time': 1.458883285522461, 'type': 'dict'}
# tokenizer_tl.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# step - 	13 - 	analyzing response - sentiment
# 				 -- confidence score - 0.801
# 				 -- analyzing response - sentiment': ['negative']}
# 				 -- analyzing response - [{'choice_1': ['negative', 0.801, 22198], 'choice_2': ['neut', 0.15, 17821], 'choice_3': ['pos', 0.048, 1066]}]
# 				 -- analyzing response - [('negative', 22198, 0.801), ('neutral', 17821, 0.15), ('positive', 1066, 0.048)]
# step - 	14 - 	executing function call - deploying - emotions
# step - 	15 - 	executing function call - getting response - emotions
# 				 -- llm_response - {'emotions': ['annoyed']}
# 				 -- output type - dict
# 				 -- usage - {'input': 108, 'output': 10, 'total': 118, 'metric': 'tokens', 'processing_time': 0.6308877468109131, 'type': 'dict'}
# step - 	16 - 	analyzing response - emotions
# 				 -- confidence score - 0.383
# 				 -- analyzing response - emotions': ['annoyed']}
# 				 -- analyzing response - {'choice_1': ['anno', 0.383, 7665], 'choice_2': ['ang', 0.211, 574], 'choice_3': ['fur', 0.114, 22613]}
# step - 	17 - 	executing function call - deploying - intent
# step - 	18 - 	executing function call - getting response - intent
# 				 -- llm_response - {'intent': ['customer service']}
# 				 -- output type - dict
# 				 -- usage - {'input': 107, 'output': 8, 'total': 115, 'metric': 'tokens', 'processing_time': 0.5598828792572021, 'type': 'dict'}
# step - 	19 - 	analyzing response - intent
# 				 -- confidence score - 0.476
# 				 -- analyzing response - intent': ['customer service']}
# 				 -- analyzing response - {'choice_1': ['customer', 0.476, 15539], 'choice_2': ['cancel', 0.467, 20713], 'choice_3': ['order', 0.009, 2098]}
# {'llm_response': {'intent': ['customer service']},
#  'dict_output': True,
#  'confidence_score': 0.476}

# %% [markdown]
# Different tools and ways to execute

# %%
agent.exec_function_call("ratings")

agent.exec_multitool_function_call(["ner","topics","tags"])
# Out:
# step - 	20 - 	executing function call - deploying - ratings
# step - 	21 - 	executing function call - getting response - ratings
# 				 -- llm_response - {'rating': ['1']}
# 				 -- output type - dict
# 				 -- usage - {'input': 107, 'output': 7, 'total': 114, 'metric': 'tokens', 'processing_time': 0.5422916412353516, 'type': 'dict'}
# step - 	22 - 	analyzing response - ratings
# 				 -- confidence score - 0.574
# 				 -- analyzing response - rating': ['1']}
# 				 -- analyzing response - [{'choice_1': ['1', 0.574, 29896], 'choice_2': ['2', 0.223, 29906], 'choice_3': ['3', 0.148, 29941]}]
# step - 	23 - 	executing function call - deploying - ner
# step - 	24 - 	executing function call - getting response - ner
# 				 -- llm_response - {'people': ['Michael Jones', 'mjones'], 'organization': ['Mixco'], 'misc': ['Tampa']}
# 				 -- output type - dict
# 				 -- usage - {'input': 114, 'output': 30, 'total': 144, 'metric': 'tokens', 'processing_time': 1.0823109149932861, 'type': 'dict'}
# step - 	25 - 	analyzing response - ner
# 				 -- confidence score - 0.973
# 				 -- analyzing response - people': ['Michael Jones', 'mjones'], 'organization': ['Mixco'], 'misc': ['Tampa']}
# 				 -- analyzing response - {'choice_1': ['Michael', 0.973, 24083], 'choice_2': ['M', 0.018, 29924], 'choice_3': ['My', 0.007, 3421]}
# step - 	26 - 	executing function call - deploying - topics
# step - 	27 - 	executing function call - getting response - topics
# 				 -- llm_response - {'topics': ['account numbers']}
# 				 -- output type - dict
# 				 -- usage - {'input': 107, 'output': 9, 'total': 116, 'metric': 'tokens', 'processing_time': 0.5747861862182617, 'type': 'dict'}
# step - 	28 - 	analyzing response - topics
# 				 -- confidence score - 0.067
# 				 -- analyzing response - topics': ['account numbers']}
# 				 -- analyzing response - {'choice_1': ['account', 0.067, 10149], 'choice_2': ['c', 0.043, 29883], 'choice_3': ['customer', 0.036, 15539]}
# step - 	29 - 	executing function call - deploying - tags
# step - 	30 - 	executing function call - getting response - tags
# 				 -- llm_response - {'tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]'}
# 				 -- output type - dict
# 				 -- usage - {'input': 107, 'output': 30, 'total': 137, 'metric': 'tokens', 'processing_time': 1.078052043914795, 'type': 'dict'}
# step - 	31 - 	analyzing response - tags
# 				 -- confidence score - 0.451
# 				 -- analyzing response - tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]'}
# 				 -- analyzing response - {'choice_1': ['M', 0.451, 29924], 'choice_2': ['T', 0.319, 29911], 'choice_3': ['My', 0.113, 3421]}
# [{'llm_response': {'people': ['Michael Jones', 'mjones'],
#    'organization': ['Mixco'],
#    'misc': ['Tampa']},
#   'dict_output': True,
#   'confidence_score': 0.973},
#  {'llm_response': {'topics': ['account numbers']},
#   'dict_output': True,
#   'confidence_score': 0.067},
#  {'llm_response': {'tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]'},
#   'dict_output': True,
#   'confidence_score': 0.451}]

# %%
agent.answer("What is a short summary?",key="summary")

response = agent.answer("What is the customer's account number and user name?", key="customer_info")
# Out:
# step - 	32 - 	executing function call - deploying - question-answer tool
# step - 	33 - 	executing function call - getting response - question - summary
# 				 -- llm_response - Michael Jones is a long-time customer of Mixco, and the company is having a negative impact on his business.  He has called Mixco four times, and the company has not responded to his calls.  His account number is 93203, and his user name is mjones.
# 				 -- output type - text
# 				 -- usage - {'input': 104, 'output': 65, 'total': 169, 'metric': 'tokens', 'processing_time': 1.9004454612731934}
# step - 	34 - 	executing function call - deploying - question-answer tool
# step - 	35 - 	executing function call - getting response - question - customer_info
# 				 -- llm_response - Customer: 93203, User: mjones
# 				 -- output type - text
# 				 -- usage - {'input': 110, 'output': 14, 'total': 124, 'metric': 'tokens', 'processing_time': 0.6713261604309082}

# %% [markdown]
# Release from memory

# %%
agent.unload_tool("ner")
agent.unload_tool("topics")
# Out:
# step - 	36 - 	unloading tool - ner
# step - 	37 - 	unloading tool - topics
# 0

# %% [markdown]
# # Show results
# 1.   Automatically gathered report
# 2.   Activity summary
# 3.   List of gathered responses

# %%
report = agent.show_report()
# Out:
# step - 	38 - 	showing all gathered reports - [{'sentiment': ['negative'], 'emotions': ['annoyed'], 'intent': ['customer service'], 'rating': ['1'], 'people': ['Michael Jones', 'mjones'], 'organization': ['Mixco'], 'misc': ['Tampa'], 'topics': ['account numbers'], 'tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]', 'summary': ['Michael Jones is a long-time customer of Mixco, and the company is having a negative impact on his business.  He has called Mixco four times, and the company has not responded to his calls.  His account number is 93203, and his user name is mjones.'], 'customer_info': ['Customer: 93203, User: mjones']}]
# report - 0 - {'sentiment': ['negative'], 'emotions': ['annoyed'], 'intent': ['customer service'], 'rating': ['1'], 'people': ['Michael Jones', 'mjones'], 'organization': ['Mixco'], 'misc': ['Tampa'], 'topics': ['account numbers'], 'tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]', 'summary': ['Michael Jones is a long-time customer of Mixco, and the company is having a negative impact on his business.  He has called Mixco four times, and the company has not responded to his calls.  His account number is 93203, and his user name is mjones.'], 'customer_info': ['Customer: 93203, User: mjones']}
# 				 -- sentiment            - ['negative']
# 				 -- emotions             - ['annoyed']
# 				 -- intent               - ['customer service']
# 				 -- rating               - ['1']
# 				 -- people               - ['Michael Jones', 'mjones']
# 				 -- organization         - ['Mixco']
# 				 -- misc                 - ['Tampa']
# 				 -- topics               - ['account numbers']
# 				 -- tags                 - ["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]
# 				 -- summary              - ['Michael Jones is a long-time customer of Mixco, and the company is having a negative impact on his business.  He has called Mixco four times, and the company has not responded to his calls.  His account number is 93203, and his user name is mjones.']
# 				 -- customer_info        - ['Customer: 93203, User: mjones']

# %%
activity_summary = agent.activity_summary()
for i, entries in enumerate(agent.response_list):
    print("update: response analysis: ", i, entries)
# Out:
# step - 	39 - 	generating activity_summary - {'inference_count': 9, 'tools_used': 8, 'tools': ['sentiment', 'ner', 'emotions', 'topics', 'intent', 'tags', 'ratings', 'answer']}
# update: response analysis:  0 {'step': 13, 'tool': 'sentiment', 'inference': 1, 'llm_response': {'sentiment': ['negative']}, 'confidence_score': 0.801, 'llm_usage': {'input': 107, 'output': 8, 'total': 115, 'metric': 'tokens', 'processing_time': 1.458883285522461, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': "\x1bsent\x1biment\x1b':\x1b ['\x1bnegative\x1b']\x1b}\x1b", 'choices': [{'choice_1': ['negative', 0.801, 22198], 'choice_2': ['neut', 0.15, 17821], 'choice_3': ['pos', 0.048, 1066]}], 'marker_tokens': [('negative', 22198, 0.801), ('neutral', 17821, 0.15), ('positive', 1066, 0.048)], 'low_confidence_choices': [], 'confidence_score': 0.801}}
# update: response analysis:  1 {'step': 16, 'tool': 'emotions', 'inference': 2, 'llm_response': {'emotions': ['annoyed']}, 'confidence_score': 0.383, 'llm_usage': {'input': 108, 'output': 10, 'total': 118, 'metric': 'tokens', 'processing_time': 0.6308877468109131, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': "\x1bem\x1bot\x1bions\x1b':\x1b ['\x1banno\x1byed\x1b']\x1b}\x1b", 'choices': [{'choice_1': ['anno', 0.383, 7665], 'choice_2': ['ang', 0.211, 574], 'choice_3': ['fur', 0.114, 22613]}, {'choice_1': ['yed', 1.0, 28133], 'choice_2': ['y', 0.0, 29891], 'choice_3': ['ying', 0.0, 5414]}], 'marker_tokens': [], 'low_confidence_choices': [{'choice_1': ['anno', 0.383, 7665], 'choice_2': ['ang', 0.211, 574], 'choice_3': ['fur', 0.114, 22613]}], 'confidence_score': 0.383}}
# update: response analysis:  2 {'step': 19, 'tool': 'intent', 'inference': 3, 'llm_response': {'intent': ['customer service']}, 'confidence_score': 0.476, 'llm_usage': {'input': 107, 'output': 8, 'total': 115, 'metric': 'tokens', 'processing_time': 0.5598828792572021, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': "\x1bintent\x1b':\x1b ['\x1bcustomer\x1b service\x1b']\x1b}\x1b", 'choices': [{'choice_1': ['customer', 0.476, 15539], 'choice_2': ['cancel', 0.467, 20713], 'choice_3': ['order', 0.009, 2098]}, {'choice_1': ['service', 0.999, 2669], 'choice_2': ['support', 0.0, 2304], 'choice_3': ['service', 0.0, 5509]}], 'marker_tokens': [], 'low_confidence_choices': [{'choice_1': ['customer', 0.476, 15539], 'choice_2': ['cancel', 0.467, 20713], 'choice_3': ['order', 0.009, 2098]}], 'confidence_score': 0.476}}
# update: response analysis:  3 {'step': 22, 'tool': 'ratings', 'inference': 4, 'llm_response': {'rating': ['1']}, 'confidence_score': 0.574, 'llm_usage': {'input': 107, 'output': 7, 'total': 114, 'metric': 'tokens', 'processing_time': 0.5422916412353516, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': "\x1brating\x1b':\x1b ['\x1b1\x1b']\x1b}\x1b", 'choices': [{'choice_1': ['1', 0.574, 29896], 'choice_2': ['2', 0.223, 29906], 'choice_3': ['3', 0.148, 29941]}], 'marker_tokens': [], 'low_confidence_choices': [{'choice_1': ['1', 0.574, 29896], 'choice_2': ['2', 0.223, 29906], 'choice_3': ['3', 0.148, 29941]}], 'confidence_score': 0.574}}
# update: response analysis:  4 {'step': 25, 'tool': 'ner', 'inference': 5, 'llm_response': {'people': ['Michael Jones', 'mjones'], 'organization': ['Mixco'], 'misc': ['Tampa']}, 'confidence_score': 0.973, 'llm_usage': {'input': 114, 'output': 30, 'total': 144, 'metric': 'tokens', 'processing_time': 1.0823109149932861, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': "\x1bpeople\x1b':\x1b ['\x1bMichael\x1b Jones\x1b',\x1b '\x1bm\x1bj\x1bones\x1b'],\x1b '\x1borgan\x1bization\x1b':\x1b ['\x1bM\x1bix\x1bco\x1b'],\x1b '\x1bm\x1bisc\x1b':\x1b ['\x1bT\x1bampa\x1b']\x1b}\x1b", 'choices': [{'choice_1': ['Michael', 0.973, 24083], 'choice_2': ['M', 0.018, 29924], 'choice_3': ['My', 0.007, 3421]}, {'choice_1': ['Jones', 0.999, 10920], 'choice_2': ["',", 0.001, 742], 'choice_3': ['J', 0.0, 435]}, {'choice_1': ["',", 0.936, 742], 'choice_2': ["'],", 0.062, 7464], 'choice_3': ["','", 0.001, 3788]}, {'choice_1': ["'", 0.996, 525], 'choice_2': ['"', 0.004, 376], 'choice_3': ["'<", 0.0, 12801]}, {'choice_1': ['m', 0.824, 29885], 'choice_2': ['M', 0.157, 29924], 'choice_3': ['Michael', 0.005, 24083]}, {'choice_1': ['j', 0.95, 29926], 'choice_2': ['ich', 0.027, 436], 'choice_3': ['ixed', 0.007, 11925]}, {'choice_1': ['ones', 0.999, 2873], 'choice_2': ['ons', 0.0, 787], 'choice_3': ['oles', 0.0, 6544]}, {'choice_1': ['M', 0.989, 29924], 'choice_2': ['My', 0.003, 3421], 'choice_3': ['X', 0.002, 29990]}, {'choice_1': ['ix', 0.993, 861], 'choice_2': ['ike', 0.002, 9345], 'choice_3': ['ic', 0.001, 293]}, {'choice_1': ['co', 1.0, 1111], 'choice_2': ['Co', 0.0, 7967], 'choice_3': ['c', 0.0, 29883]}, {'choice_1': ['T', 0.707, 29911], 'choice_2': ['My', 0.222, 3421], 'choice_3': ['F', 0.025, 29943]}, {'choice_1': ['ampa', 1.0, 20056], 'choice_2': ['amp', 0.0, 1160], 'choice_3': ['or', 0.0, 272]}], 'marker_tokens': [], 'low_confidence_choices': [{'choice_1': ['organ', 0.525, 6388], 'choice_2': ['location', 0.45, 5479], 'choice_3': ['place', 0.011, 6689]}, {'choice_1': ["['", 0.578, 6024], 'choice_2': ['[],', 0.408, 19997], 'choice_3': ['["', 0.004, 6796]}, {'choice_1': ["']", 0.697, 2033], 'choice_2': ["',", 0.29, 742], 'choice_3': [',', 0.007, 29892]}], 'confidence_score': 0.973}}
# update: response analysis:  5 {'step': 28, 'tool': 'topics', 'inference': 6, 'llm_response': {'topics': ['account numbers']}, 'confidence_score': 0.067, 'llm_usage': {'input': 107, 'output': 9, 'total': 116, 'metric': 'tokens', 'processing_time': 0.5747861862182617, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': "\x1btop\x1bics\x1b':\x1b ['\x1baccount\x1b numbers\x1b']\x1b}\x1b", 'choices': [{'choice_1': ['account', 0.067, 10149], 'choice_2': ['c', 0.043, 29883], 'choice_3': ['customer', 0.036, 15539]}, {'choice_1': ['numbers', 0.271, 3694], 'choice_2': ['s', 0.251, 29879], 'choice_3': ['information', 0.127, 2472]}], 'marker_tokens': [], 'low_confidence_choices': [{'choice_1': ['account', 0.067, 10149], 'choice_2': ['c', 0.043, 29883], 'choice_3': ['customer', 0.036, 15539]}, {'choice_1': ['numbers', 0.271, 3694], 'choice_2': ['s', 0.251, 29879], 'choice_3': ['information', 0.127, 2472]}], 'confidence_score': 0.067}}
# update: response analysis:  6 {'step': 31, 'tool': 'tags', 'inference': 7, 'llm_response': {'tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]'}, 'confidence_score': 0.451, 'llm_usage': {'input': 107, 'output': 30, 'total': 137, 'metric': 'tokens', 'processing_time': 1.078052043914795, 'type': 'dict'}, 'work_iteration': 0, 'dict_output': True, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA', 'logit_analysis': {'ryg_string': '\x1btags\x1b\':\x1b \'\x1b["\x1bM\x1bix\x1bco\x1b",\x1b "\x1bT\x1bampa\x1b,\x1b Florida\x1b",\x1b "\x1bMy\x1b name\x1b is\x1b Michael\x1b Jones\x1b",\x1b "\x1b9\x1b3\x1b2\x1b0\x1b3\x1b"]\x1b\'}\x1b', 'choices': [{'choice_1': ['M', 0.451, 29924], 'choice_2': ['T', 0.319, 29911], 'choice_3': ['My', 0.113, 3421]}, {'choice_1': ['ix', 0.953, 861], 'choice_2': ['ike', 0.035, 9345], 'choice_3': ['ic', 0.003, 293]}, {'choice_1': ['co', 0.999, 1111], 'choice_2': ['Co', 0.0, 7967], 'choice_3': ['c', 0.0, 29883]}, {'choice_1': ['",', 0.975, 613], 'choice_2': ['product', 0.018, 3234], 'choice_3': ['"', 0.002, 29908]}, {'choice_1': ['"', 0.996, 376], 'choice_2': ['""', 0.003, 5124], 'choice_3': ['"-', 0.0, 11663]}, {'choice_1': ['T', 0.873, 29911], 'choice_2': ['My', 0.018, 3421], 'choice_3': ['my', 0.014, 1357]}, {'choice_1': ['ampa', 1.0, 20056], 'choice_2': ['amp', 0.0, 1160], 'choice_3': ['ennessee', 0.0, 21539]}, {'choice_1': [',', 0.765, 29892], 'choice_2': ['",', 0.234, 613], 'choice_3': ['"]', 0.0, 3108]}, {'choice_1': ['Florida', 0.996, 13813], 'choice_2': ['F', 0.002, 383], 'choice_3': ['",', 0.001, 613]}, {'choice_1': ['",', 0.999, 613], 'choice_2': ['.",', 0.0, 19602], 'choice_3': ['"]', 0.0, 3108]}, {'choice_1': ['"', 0.998, 376], 'choice_2': ['""', 0.001, 5124], 'choice_3': ['"-', 0.001, 11663]}, {'choice_1': ['My', 0.7, 3421], 'choice_2': ['Michael', 0.265, 24083], 'choice_3': ['M', 0.019, 29924]}, {'choice_1': ['name', 0.998, 1024], 'choice_2': ['Name', 0.001, 4408], 'choice_3': ['name', 0.0, 978]}, {'choice_1': ['is', 0.952, 338], 'choice_2': ['",', 0.044, 613], 'choice_3': ['"]', 0.002, 3108]}, {'choice_1': ['Michael', 0.952, 5765], 'choice_2': ['",', 0.042, 613], 'choice_3': ['"]', 0.002, 3108]}, {'choice_1': ['Jones', 0.992, 10920], 'choice_2': ['",', 0.007, 613], 'choice_3': ['"]', 0.0, 3108]}, {'choice_1': ['",', 0.619, 613], 'choice_2': [',', 0.355, 29892], 'choice_3': ['"]', 0.007, 3108]}, {'choice_1': ['"', 0.997, 376], 'choice_2': ['"-', 0.002, 11663], 'choice_3': ['""', 0.0, 5124]}, {'choice_1': ['9', 0.877, 29929], 'choice_2': ['M', 0.032, 29924], 'choice_3': ['3', 0.025, 29941]}, {'choice_1': ['3', 1.0, 29941], 'choice_2': ['2', 0.0, 29906], 'choice_3': ['",', 0.0, 613]}, {'choice_1': ['2', 1.0, 29906], 'choice_2': ['",', 0.0, 613], 'choice_3': ['3', 0.0, 29941]}, {'choice_1': ['0', 0.999, 29900], 'choice_2': ['",', 0.001, 613], 'choice_3': ['"]', 0.0, 3108]}, {'choice_1': ['3', 0.999, 29941], 'choice_2': ['2', 0.0, 29906], 'choice_3': ['4', 0.0, 29946]}], 'marker_tokens': [], 'low_confidence_choices': [{'choice_1': ['M', 0.451, 29924], 'choice_2': ['T', 0.319, 29911], 'choice_3': ['My', 0.113, 3421]}, {'choice_1': ['My', 0.7, 3421], 'choice_2': ['Michael', 0.265, 24083], 'choice_3': ['M', 0.019, 29924]}, {'choice_1': ['",', 0.619, 613], 'choice_2': [',', 0.355, 29892], 'choice_3': ['"]', 0.007, 3108]}, {'choice_1': ['"]', 0.636, 3108], 'choice_2': ['",', 0.364, 613], 'choice_3': ['"],', 0.0, 12436]}], 'confidence_score': 0.451}}
# update: response analysis:  7 {'step': 33, 'tool': 'answer', 'inference': 8, 'llm_response': 'Michael Jones is a long-time customer of Mixco, and the company is having a negative impact on his business.  He has called Mixco four times, and the company has not responded to his calls.  His account number is 93203, and his user name is mjones.', 'llm_usage': {'input': 104, 'output': 65, 'total': 169, 'metric': 'tokens', 'processing_time': 1.9004454612731934}, 'work_iteration': 0, 'dict_output': False, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA'}
# update: response analysis:  8 {'step': 35, 'tool': 'answer', 'inference': 9, 'llm_response': 'Customer: 93203, User: mjones', 'llm_usage': {'input': 110, 'output': 14, 'total': 124, 'metric': 'tokens', 'processing_time': 0.6713261604309082}, 'work_iteration': 0, 'dict_output': False, 'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA'}

# %%
output = {"report": report, "activity_summary": activity_summary, "journal": agent.journal}

print(output)
# Out:
# {'report': [{'sentiment': ['negative'], 'emotions': ['annoyed'], 'intent': ['customer service'], 'rating': ['1'], 'people': ['Michael Jones', 'mjones'], 'organization': ['Mixco'], 'misc': ['Tampa'], 'topics': ['account numbers'], 'tags': '["Mixco", "Tampa, Florida", "My name is Michael Jones", "93203"]', 'summary': ['Michael Jones is a long-time customer of Mixco, and the company is having a negative impact on his business.  He has called Mixco four times, and the company has not responded to his calls.  His account number is 93203, and his user name is mjones.'], 'customer_info': ['Customer: 93203, User: mjones'], 'source': {'text': 'My name is Michael Jones, and I am a long-time customer.  The Mixco product is not working currently, and it is having a negative impact on my business, as we can not deliver our products while it is down. This is the fourth time that I have called.  My account number is 93203, and my user name is mjones. Our company is based in Tampa, Florida.', 'file_source': 'NA', 'page_num': 'NA'}}], 'activity_summary': {'inference_count': 9, 'tools_used': 8, 'tools': ['sentiment', 'ner', 'emotions', 'topics', 'intent', 'tags', 'ratings', 'answer']}, 'journal': ['creating object - ready to start processing.', 'loading new processing text - 1 new entries', 'loading tool - sentiment', 'loading tool - ner', 'loading tool - emotions', 'loading tool - topics', 'loading tool - intent', 'loading tool - tags', 'loading tool - ratings', 'loading tool - answer', 'executing function call - deploying - sentiment ', "executing function call - getting response - sentiment\n\t\t\t\t -- llm_response - {'sentiment': ['negative']}\n\t\t\t\t -- output type - dict\n\t\t\t\t -- usage - {'input': 107, 'output': 8, 'total': 115, 'metric': 'tokens', 'processing_time': 1.458883285522461, 'type': 'dict'}", "analyzing response - sentiment\n\t\t\t\t -- confidence score - 0.801\n\t\t\t\t -- analyzing response - \x1bsent\x1biment\x1b':\x1b ['\x1bnegative\x1b']\x1b}\x1b\n\t\t\t\t -- analyzing response - [{'choice_1': ['negative', 0.801, 22198], 'choice_2': ['neut', 0.15, 17821], 'choice_3': ['pos', 0.048, 1066]}]\n\t\t\t\t -- analyzing response - [('negative', 22198, 0.801), ('neutral', 17821, 0.15), ('positive', 1066, 0.048)]", 'executing function call - deploying - emotions ', "executing function call - getting response - emotions\n\t\t\t\t -- llm_response - {'emotions': ['annoyed']}\n\t\t\t\t -- output type - dict\n\t\t\t\t -- usage - {'input': 108, 'output': 10, 'total': 118, 'metric': 'tokens', 'processing_time': 0.6308877468109131, 'type': 'dict'}", "analyzing response - emotions\n\t\t\t\t -- confidence score - 0.383\n\t\t\t\t -- analyzing response - \x1bem\x1bot\x1bions\x1b':\x1b ['\x1banno\x1byed\x1b']\x1b}\x1b\n\t\t\t\t -- analyzing response - {'choice_1': ['anno', 0.383, 7665], 'choice_2': ['ang', 0.211, 574], 'choice_3': ['fur', 0.114, 22613]}", 'executing function call - deploying - intent ', "executing function call - getting response - intent\n\t\t\t\t -- llm_response - {'intent': ['customer service']}\n\t\t\t\t -- output type - dict\n\t\t\t\t -- usage - {'input': 107, 'output': 8, 'total': 115, 'metric': 'tokens', 'processing_time': 0.5598828792572021, 'type': 'dict'}", "analyzing response - intent\n\t\t\t\t -- confidence score - 0.476\n\t\t\t\t -- analyzing response - \x1bintent\x1b':\x1b ['\x1bcustomer\x1b service\x1b']\x1b}\x1b\n\t\t\t\t -- analyzing response - {'choice_1': ['customer', 0.476, 15539], 'choice_2': ['cancel', 0.467, 20713], 'choice_3': ['order', 0.009, 2098]}", 'executing function call - deploying - ratings ', "executing function call - getting response - ratings\n\t\t\t\t -- llm_response - {'rating': ['1']}\n\t\t\t\t -- output type - dict\n\t\t\t\t -- usage - {'input': 107, 'output': 7, 'total': 114, 'metric': 'tokens', 'processing_time': 0.5422916412353516, 'type': 'dict'}", "analyzing response - ratings\n\t\t\t\t -- confidence score - 0.574\n\t\t\t\t -- analyzing response - \x1brating\x1b':\x1b ['\x1b1\x ...
